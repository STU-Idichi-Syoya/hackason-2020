# %%
import pandas as pd

df=pd.read_csv("zenkoku.csv")

# %%
df.dropna(subset=["事業所名"],inplace=True)

# %%
df["住所"]=df["都道府県"]+df["市区町村"]+df["事業所住所"]

# %%
df=df[df["市区町村"]=="新宿区"]
len(df)
# Out:
# 340

# %%
# df["住所"].to_clipboard(header=False, index=False)

# %%
df.to_csv("random.csv")

# %%
new=df["住所"].str.replace("\uff0d","-")
new.to_csv("500-osaka.csv",encoding="SHIFT-JIS")

# %%
# Out:
# Empty DataFrame
# Columns: [住所CD, 都道府県CD, 市区町村CD, 町域CD, 郵便番号, 事業所フラグ, 廃止フラグ, 都道府県, 都道府県カナ, 市区町村, 市区町村カナ, 町域, 町域カナ, 町域補足, 京都通り名, 字丁目, 字丁目カナ, 補足, 事業所名, 事業所名カナ, 事業所住所, 新住所CD, 住所]
# Index: []
#
# [0 rows x 23 columns]

# %%
import requests
from bs4 import BeautifulSoup
import time
from tqdm import tqdm
from multiprocessing import Pool
def get_lat_lon_from_address(address_l):
    """
    address_lにlistの形で住所を入れてあげると、latlonsという入れ子上のリストで緯度経度のリストを返す関数。
    >>>>get_lat_lon_from_address(['東京都文京区本郷7-3-1','東京都文京区湯島３丁目３０−１'])
    [['35.712056', '139.762775'], ['35.707771', '139.768205']]
    """
    url = 'http://www.geocoding.jp/api/'
    lata,lona = [],[]
    for address in tqdm(address_l):
        payload = {"v": 1.1, 'q': address}
        r = requests.get(url, params=payload)
        ret = BeautifulSoup(r.content,'lxml')
        
        if ret.find('error'):
            print("ER!!")
            lat=lon=None
        else:
            lat = ret.find('lat').string
            lon = ret.find('lng').string
        lata.append(lat)
        lona.append(lon)
        time.sleep(2)
    return lata,lona

# %%
adr=df["住所"].tolist()

# %%
adr
# Out:
# ['東京都新宿区愛住町２２第三山田ビル４Ｆ',
#  '東京都新宿区揚場町２番１号軽子坂ＭＮビル５階',
#  '東京都新宿区揚場町２－２６',
#  '東京都新宿区揚場町２－１８',
#  '東京都新宿区揚場町２－１',
#  '東京都新宿区荒木町２－３',
#  '東京都新宿区市谷加賀町１丁目１－１',
#  '東京都新宿区市谷砂土原町２丁目６',
#  '東京都新宿区市谷砂土原町１－２－５９',
#  '東京都新宿区市谷砂土原町１丁目２保健会館内',
#  '東京都新宿区市谷砂土原町３丁目５',
#  '東京都新宿区市谷砂土原町１－２－５９',
#  '東京都新宿区市谷砂土原町１－２－５９',
#  '東京都新宿区市谷砂土原町２丁目４番地',
#  '東京都新宿区市谷田町１丁目１８番',
#  '東京都新宿区市谷田町１丁目１８',
#  '東京都新宿区市谷船河原町１５',
#  '東京都新宿区市谷船河原町１１',
#  '東京都新宿区市谷本村町４２－８',
#  '東京都新宿区市谷本村町３－２１経済法令ビル',
#  '東京都新宿区市谷本村町３－２１',
#  '東京都新宿区市谷本村町１－１住友市ケ谷ビル',
#  '東京都新宿区市谷本村町３－２１',
#  '東京都新宿区市谷本村町１０－７',
#  '東京都新宿区市谷本村町３－２６',
#  '東京都新宿区市谷本村町１０－５',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町１０番１号',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町２－３',
#  '東京都新宿区市谷本村町２－１２',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区市谷本村町５－１',
#  '東京都新宿区岩戸町１８日交神楽坂ビル',
#  '東京都新宿区岩戸町２',
#  '東京都新宿区榎町７',
#  '東京都新宿区榎町７',
# ...

# %%
lat,lon=get_lat_lon_from_address(adr)
# Out:
# ...
# 100%|██████████| 340/340 [21:21<00:00,  3.77s/it]

# %%
import numpy as np
lat=np.array(lat,dtype="float64")
lat
# Out:
# array([35.691802, 35.701951, 35.702407, 35.702687, 35.701819, 35.688804,
#        35.695623, 35.695972, 35.694281, 35.693781, 35.696412, 35.694281,
#        35.694281, 35.695795, 35.693687, 35.693687, 35.698347, 35.698325,
#        35.69277 , 35.690911, 35.690894, 35.691178, 35.690894, 35.694615,
#        35.691017, 35.694496, 35.692694, 35.692694, 35.694957, 35.692694,
#        35.692694, 35.692694, 35.692694, 35.692694, 35.690668, 35.690175,
#        35.692694, 35.692694, 35.692694, 35.692694, 35.692694, 35.701348,
#        35.701962, 35.705853, 35.705853,       nan, 35.704528, 35.702307,
#        35.702307, 35.70102 , 35.701231, 35.699474, 35.701231, 35.701897,
#        35.70102 , 35.705887, 35.702237, 35.702226,       nan, 35.701588,
#        35.703703, 35.699452, 35.693893, 35.695293, 35.696697, 35.693893,
#        35.693893, 35.694361, 35.697867, 35.710307, 35.710807, 35.69702 ,
#        35.696088, 35.698165, 35.696092, 35.699569, 35.687244, 35.680088,
# ...

# %%
lon=np.array(lon,dtype="float64")
lon
# Out:
# array([139.720479, 139.74277 , 139.74331 , 139.742814, 139.742708,
#        139.72232 , 139.731017, 139.735585, 139.735923, 139.735982,
#        139.735646, 139.735923, 139.735923, 139.734988, 139.736605,
#        139.736605, 139.739776, 139.740426, 139.730077, 139.731341,
#        139.731327, 139.73299 , 139.731327, 139.731791, 139.732256,
#        139.731179, 139.728781, 139.728781, 139.730908, 139.728781,
#        139.728781, 139.728781, 139.728781, 139.728781, 139.732378,
#        139.731133, 139.728781, 139.728781, 139.728781, 139.728781,
#        139.728781, 139.73756 , 139.737523, 139.728899, 139.728899,
#               nan, 139.727263, 139.708569, 139.708569, 139.70872 ,
#        139.706694, 139.707472, 139.706694, 139.706751, 139.70872 ,
#        139.706035, 139.707457, 139.708011,        nan, 139.744366,
#        139.736213, 139.741369, 139.703426, 139.701969, 139.701143,
#        139.703426, 139.703426, 139.70027 , 139.701018, 139.683101,
# ...

# %%
lon=pd.Series(lon)
lon
# Out:
# 0      139.720479
# 1      139.742770
# 2      139.743310
# 3      139.742814
# 4      139.742708
#           ...
# 335    139.714752
# 336    139.714752
# 337    139.723767
# 338    139.723767
# 339    139.723213
# Length: 340, dtype: float64

# %%
ndf=df.drop(columns="lon")

# %%
ndf.head()
# Out:
#             住所CD  都道府県CD  市区町村CD       町域CD      郵便番号  事業所フラグ  廃止フラグ 都道府県  \
# 46440  160857100      13   13104  131040001  160-8571       1      0  東京都
# 46444  162858500      13   13104  131040004  162-8585       1      0  東京都
# 46445  162855600      13   13104  131040004  162-8556       1      0  東京都
# 46446  162858700      13   13104  131040004  162-8587       1      0  東京都
# 46447  162856500      13   13104  131040004  162-8565       1      0  東京都
#
#        都道府県カナ 市区町村  ...  字丁目 字丁目カナ   補足             事業所名  \
# 46440  トウキョウト  新宿区  ...  NaN   NaN  NaN        株式会社　太田出版
# 46444  トウキョウト  新宿区  ...  NaN   NaN  NaN    株式会社　ＴＫＣ　東京本社
# 46445  トウキョウト  新宿区  ...  NaN   NaN  NaN  株式会社　銀座コージーコーナー
# 46446  トウキョウト  新宿区  ...  NaN   NaN  NaN        土地興業　株式会社
# 46447  トウキョウト  新宿区  ...  NaN   NaN  NaN      大興電子通信　株式会社
#
#                           事業所名カナ             事業所住所 新住所CD  \
# 46440          カブシキカイシヤ　オオタシユツパン     愛住町２２第三山田ビル４Ｆ   NaN
# 46444  カブシキガイシヤ　テイケ－シ－　トウキヨウホンシヤ  揚場町２番１号軽子坂ＭＮビル５階   NaN
# ...

# %%
df["lon"]=lon

# %%
dropped=df.dropna(subset=["lat","lon"])

# %%
print(len(df))
df.tail()
# Out:
# 340
#             住所CD  都道府県CD  市区町村CD       町域CD      郵便番号  事業所フラグ  廃止フラグ 都道府県  \
# 47465  162802200      13   13104  131040090  162-8022       1      0  東京都
# 47466  162866800      13   13104  131040090  162-8668       1      0  東京都
# 47470  162871800      13   13104  131040093  162-8718       1      0  東京都
# 47471  162871700      13   13104  131040093  162-8717       1      0  東京都
# 47472  162866900      13   13104  131040093  162-8669       1      0  東京都
#
#        都道府県カナ 市区町村  ... 字丁目カナ   補足        事業所名               事業所名カナ    事業所住所  \
# 47465  トウキョウト  新宿区  ...   NaN  NaN  総務省　人事・恩給局  ソウムシヨウ　ジンジ・オンキユウキヨク  若松町１９－１
# 47466  トウキョウト  新宿区  ...   NaN  NaN     総務省　統計局       ソウムシヨウ　トウケイキヨク  若松町１９－１
# 47470  トウキョウト  新宿区  ...   NaN  NaN    株式会社　学文社      カブシキガイシヤ　ガクブンシヤ  早稲田町５－４
# 47471  トウキョウト  新宿区  ...   NaN  NaN    株式会社　学文社      カブシキガイシヤ　ガクブンシヤ  早稲田町５－４
# 47472  トウキョウト  新宿区  ...   NaN  NaN     綜通　株式会社        ソウツウ　カブシキガイシヤ   早稲田町６９
#
#       新住所CD             住所        lat lon lonn
# ...

# %%
ndf.to_csv("adr-tokyo.csv")

# %%
lon["lat"]=lat

# %%
lon.head()
# Out:
# 0     139.72
# 1    139.743
# 2    139.743
# 3    139.743
# 4    139.743
# dtype: object

# %%
newdf=pd.DataFrame()

# %%
newdf["lon"]=np.array([139.720479, 139.74277 , 139.74331 , 139.742814, 139.742708,
       139.72232 , 139.731017, 139.735585, 139.735923, 139.735982,
       139.735646, 139.735923, 139.735923, 139.734988, 139.736605,
       139.736605, 139.739776, 139.740426, 139.730077, 139.731341,
       139.731327, 139.73299 , 139.731327, 139.731791, 139.732256,
       139.731179, 139.728781, 139.728781, 139.730908, 139.728781,
       139.728781, 139.728781, 139.728781, 139.728781, 139.732378,
       139.731133, 139.728781, 139.728781, 139.728781, 139.728781,
       139.728781, 139.73756 , 139.737523, 139.728899, 139.728899,
              None, 139.727263, 139.708569, 139.708569, 139.70872 ,
       35.690055, 35.6972  , 35.690087, 35.696831, 35.695925, 35.686462,
       35.68759 , 35.68959 , 35.683454, 35.692892, 35.686809, 35.68759 ,
       35.697387, 35.690611, 35.683952, 35.688784, 35.692539, 35.688045,
       35.68554 , 35.688616, 35.688616, 35.688616, 35.687984, 35.687984,
       35.687957, 35.688045, 35.68554 , 35.686588, 35.691566, 35.691566,
       35.690461, 35.693552, 35.689486, 35.687927, 35.688045, 35.693132,
       35.682955, 35.682955, 35.682955, 35.693132, 35.693132, 35.693132,
       35.693132, 35.68554 , 35.693132, 35.685427, 35.692326, 35.692326,
       35.692326, 35.68554 , 35.685427, 35.68554 , 35.689705, 35.693177,
       35.692951, 35.697471, 35.692951, 35.692951, 35.692951, 35.692951,
       35.692951, 35.692951, 35.691891, 35.692951, 35.691891, 35.69191 ,
       35.69191 , 35.69191 , 35.69191 , 35.691213, 35.691338, 35.691338,
       35.692951, 35.694604, 35.693973, 35.690276, 35.689782, 35.69191 ,
       35.692905, 35.692539, 35.692968, 35.696231, 35.691351, 35.692697,
       35.691891, 35.691891, 35.691891, 35.691891, 35.691891, 35.691891,
       35.69684 , 35.707502, 35.70834 , 35.707492, 35.708022, 35.710094,
       35.710098, 35.713746, 35.713357, 35.71227 , 35.707672, 35.706339,
       35.706796, 35.696959, 35.697044, 35.701614, 35.69834 , 35.705576,
       35.705267, 35.707776, 35.704695, 35.700727, 35.70222 , 35.70222 ,
       35.702887, 35.698389, 35.705663, 35.700859, 35.679456, 35.680432,
       35.679201, 35.679456, 35.7072  , 35.706682, 35.706467, 35.707232,
       35.708363, 35.704223, 35.703056, 35.700466, 35.700466, 35.68781 ,
       35.687247, 35.687158, 35.687158, 35.688358, 35.689177, 35.690224,
       35.686902, 35.69122 , 35.688333, 35.688175, 35.699265, 35.700746,
       35.700746, 35.705354, 35.705354, 35.705931],dtype="float64"
)

# %%
newdf.dtypes
lon=newdf["lon"]
lat=newdf["lat"]

lon_f=lon.astype(dtype="float64")
lat_f=lat.astype(dtype="float64")

# %%
lon_f.dtype
# Out:
# dtype('float64')

# %%
nndf["lon"]=lon_f
nndf["lat"]=lat_f

# %%
# nndf.head()
(nndf["lat"].dtype)
# Out:
# dtype('float64')

# %%
lon_f+=lat_f

# %%
lon_f.head()
# Out:
# 0    175.412281
# 1    175.444721
# 2    175.445717
# 3    175.445501
# 4    175.444527
# Name: lon, dtype: float64

# %%
newdf
# Out:
#             lon        lat
# 0    139.720479  35.691802
# 1    139.742770  35.701951
# 2    139.743310  35.702407
# 3    139.742814  35.702687
# 4    139.742708  35.701819
# ..          ...        ...
# 335  139.714752  35.700746
# 336  139.714752  35.700746
# 337  139.723767  35.705354
# 338  139.723767  35.705354
# 339  139.723213  35.705931
#
# [340 rows x 2 columns]

# %%
ss=[]
with open("final-place.csv","w") as f:
    for i in range(len(newdf)):
        s=[nndf[i:i+1]["事業所名"].values[0],newdf[i:i+1]["lat"].values[0],newdf[i:i+1]["lon"].values[0]]

        ss.append(s)

# %%
import pickle
with open("d.pkl","wb") as f:
    pickle.dump(ss,f)
